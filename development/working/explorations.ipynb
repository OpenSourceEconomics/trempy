# %% [markdown]
# # Explorations of dataset
#
# This notebook allows for quick exploration of the observed dataset.

# %%
import pandas as pd
DATA_DIR = '../../../data/original'
df_base = pd.read_excel('../../../data/original/risk_data.xlsx', header=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4a962178f7af> in <module>()
#       1 import pandas as pd
#       2 DATA_DIR = '../../../data/original'
# ----> 3 df_base = pd.read_excel('../../../data/original/risk_data.xlsx', header=0)
#
# ~/.envs/interalpy/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~/.envs/interalpy/lib/python3.6/site-packages/pandas/io/excel.py in read_excel(io, sheet_name, header, skiprows, skip_footer, index_col, names, usecols, parse_dates, date_parser, na_values, thousands, convert_float, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     228
# ...

# %%
import sys
sys.path.insert(0, 'data/')
from data_auxiliary import drop_nuisance_information
df_base_cut = drop_nuisance_information(df_base)
cond = df_base_cut['Player.endowment_charity'] == 40
df = df_base_cut[cond]

df['Player.i2_heads_outcome'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-cbea41d33758> in <module>()
#       1 import sys
#       2 sys.path.insert(0, 'data/')
# ----> 3 from data_auxiliary import drop_nuisance_information
#       4 df_base_cut = drop_nuisance_information(df_base)
#       5 cond = df_base_cut['Player.endowment_charity'] == 40
#
# ModuleNotFoundError: No module named 'data_auxiliary'

# %%
df = pd.read_pickle('data/observed.interalpy.pkl')

df["Compensation"].loc[slice(None), slice(12, 12)].describe()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.envs/interalpy/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      98         try:
# ---> 99             return read_wrapper(lambda f: pkl.load(f))
#     100         except Exception:
#
# ~/.envs/interalpy/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      81                             compression=inferred_compression,
# ---> 82                             is_text=False)
#      83         try:
#
# ~/.envs/interalpy/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     395             # Python 3 and binary mode
# --> 396             f = open(path_or_buf, mode)
#     397         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/observed.interalpy.pkl'
#
# ...

# %%
df = pd.read_pickle('data/observed_extended.interalpy.pkl')
sorted(df['Question'].unique())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.envs/interalpy/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      98         try:
# ---> 99             return read_wrapper(lambda f: pkl.load(f))
#     100         except Exception:
#
# ~/.envs/interalpy/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      81                             compression=inferred_compression,
# ---> 82                             is_text=False)
#      83         try:
#
# ~/.envs/interalpy/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     395             # Python 3 and binary mode
# --> 396             f = open(path_or_buf, mode)
#     397         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/observed_extended.interalpy.pkl'
#
# ...

# %%
before = pd.read_pickle('data/before_application.interalpy.pkl')
after = pd.read_pickle('data/after_application.interalpy.pkl')

# %%
before.head()
# Out:
#   Participant.code  Player.endowment_self  Player.endowment_charity  \
# 1         n7ifdw34                     40                         0
# 2         04znblti                      0                        40
# 3         a074ggsg                      0                        40
# 6         dl4r4e95                     40                         0
# 7         kdwhspge                     25                         0
#
#    Player.i1  Player.i1_goes_to_charity  Player.i2_heads_prob  \
# 1        -10                          0                   0.5
# 2        -10                          1                   0.5
# 3        -10                          1                   0.8
# 6        -10                          0                   0.5
# 7        -10                          0                   1.0
#
#    Player.i2_heads_outcome  Player.i2_tails_outcome  \
# 1                       14                      -14
# 2                       14                      -14
# ...

# %%
after = pd.read_pickle('estimation/observed.interalpy.pkl')
after.sort_index(inplace=True)
after.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.envs/interalpy/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      98         try:
# ---> 99             return read_wrapper(lambda f: pkl.load(f))
#     100         except Exception:
#
# ~/.envs/interalpy/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      81                             compression=inferred_compression,
# ---> 82                             is_text=False)
#      83         try:
#
# ~/.envs/interalpy/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     395             # Python 3 and binary mode
# --> 396             f = open(path_or_buf, mode)
#     397         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'estimation/observed.interalpy.pkl'
#
# ...

# %% [markdown]
# # Code Explorations

# %%
import os
print(os.getcwd())
df = pd.read_pickle('data.interalpy.pkl')
df = df[df['Question'] == 1]
df['Compensation'].value_counts()

from PyPDF2 import PdfFileMerger
import matplotlib.pyplot as plt
import seaborn as sns

#sns.set(color_codes=True)
#sns.distplot(df['Compensation'])
#plt.show()

df['is_truncated'] = df['Compensation'] == -0.1

df['temp'] = df['is_truncated'] * df['Question'] + (1 - df['is_truncated']) * df['Compensation']

df.head(100)
# Out:
# /home/peisenha/external_storage/ownCloud/office/workspace/research/papers/intertemporal_altruism/sandbox/peisenha/prototype_revised/development/working
#                      Individual  Question  Compensation    Latent  \
# Individual Question
# 0          1                  0         1     -0.096608 -0.096608
# 1          1                  1         1      2.640459  2.640459
# 2          1                  2         1      0.310136  0.310136
# 3          1                  3         1      0.554671  0.554671
# 4          1                  4         1      0.053188  0.053188
# 5          1                  5         1     -0.100000 -0.439659
# 6          1                  6         1      1.916485  1.916485
# 7          1                  7         1      1.272649  1.272649
# 8          1                  8         1      3.381387  3.381387
# 9          1                  9         1      3.227165  3.227165
# 10         1                 10         1      1.879729  1.879729
# ...

# %%
import numpy as np


def utility(alpha, x):
    """This function calculates the state utility."""
    if alpha == 1:
        rslt = np.log(x)
    else:
        rslt = x ** (1 - alpha) / (1 - alpha)
    
    return rslt

grid = np.linspace(15, 80)

import seaborn as sns
import pandas as pd
y_values = []

alpha = 0.1
for x in grid:
    y_values = utility(alpha, grid)

df = sns.load_dataset("anscombe")
df = pd.DataFrame([grid, y_values]).transpose()
df['x'] = df[0]
df['y'] = df[1]
sns.lmplot(x='x', y = 'y', data=df)
